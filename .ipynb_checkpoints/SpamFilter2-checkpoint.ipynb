# %%
import os, glob, math
path = "emails/bare/part1"
# os.path = returns current directory
path = os.path.join(os.getcwd(), path)

class email:
    # represents each email 
    def __init__(self):
        self.classType = "undefined"
        self.words = []
    def openFile(self, classType, filePath):
        self.classType = classType
        with open(filePath) as myFile:
            data = myFile.read()
            words = set()
            words = data.split()
            self.words = set(words)

class dictionary:
    # word dictionary where words are stored and 
    def __init__(self):
#         self.spamWords = []
#         self.hamWords = []
        self.words = []
        self.spamCount = 0
        self.hamCount = 0
    def update(self, mail):
        tempWordBag = []
        for word in self.words:
            tempWordBag.append(word[0])
        mailWords = mail.words
        if(mail.classType == 'ham'):
            self.hamCount += 1
        else:
            self.spamCount += 1
        for mword in mailWords:
            if(mword in tempWordBag):
                index = tempWordBag.index(mword)
                sword = self.words[index]
                if(mail.classType == 'ham'):
                    sword[1] += 1
                else:
                    sword[2] += 1
            else:
                sword = [mword, 0, 0]
                if(mail.classType == 'ham'):
                    sword[1] += 1
                else:
                    sword[2] += 1
                self.words.append(sword)
                
#         if(mail.classType == 'ham'):
#             self.hamCount += 1
#             for word in self.hamWords:
#                 tempWordBag.append(word[0])
#             mailWords = mail.words
#             for mword in mailWords:
#                 if(mword in tempWordBag):
#                     index = tempWordBag.index(mword)
#                     sword = self.hamWords[index]
#                     sword[1] += 1
#                 else:
#                     sword = [mword, 1]
#                     self.hamWords.append(sword)
#         else:
#             self.spamCount += 1
#             for word in self.spamWords:
#                 tempWordBag.append(word[0])
#             mailWords = mail.words
#             for mword in mailWords:
#                 if(mword in tempWordBag):
#                     index = tempWordBag.index(mword)
#                     sword = self.spamWords[index]
#                     sword[1] += 1
#                 else:
#                     sword = [mword, 1]
#                     self.spamWords.append(sword)
    def display(self):
        print('spam count: ', self.spamCount)
        print('ham count: ', self.hamCount)
        for word in self.words:
            print(word)
#         print('spam words')
#         for word in self.spamWords:
#             print(word)
#         print('ham words')
#         for word in self.hamWords:
#             print(word)
        
class mutualInformation:
    def __init__(self, countHam, countSpam):
        self.probHam = 1.0 * countHam / (countHam+countSpam)
        self.probSpam = 1.0 * countSpam / (countHam+countSpam)
        self.words = []
    def probOfWord(self, words):
        countH = 0
        countS = 0
        for word in words:
            countH += word[1]
            countS += word[2]
        count = countH+countS
        for tempWord in words:
#             print(tempWord)
            # probability of a word appearing
            wordprob = 1.0 * (tempWord[1]+tempWord[2])/ count
            # calculate the probability of word given a class(ham)
            hwordprob = 1.0 * self.probHam * (1.0 * tempWord[1]/countH)
            # calculate the probability of word given a class(ham), P(X,C)*log(P(X,C)/(P(X)*P(C)))
            if(hwordprob == 0):
                htemp = 0
            else:
                htemp = hwordprob * math.log(hwordprob/(wordprob*self.probHam))
            # calculate the probability of word given a class(ham)
            swordprob = 1.0 * self.probSpam * (1.0 * tempWord[2]/count)
            # calculate the probability of word given a class(ham), P(X,C)*log(P(X,C)/(P(X)*P(C)))
            if(swordprob == 0):
                stemp = 0
            else:
                stemp = swordprob * math.log(swordprob/(wordprob*self.probSpam))
            temp = htemp + stemp
#             print(temp)
            word = [tempWord[0], temp]
            self.words.append(word)
        
#     def compute(self, word, spam, ham):
#         # word [word, ham, spam]
#         probWordinClass = word[1]/ham
#         print(prob)
        
wordDict = dictionary()
mail = email()
for filePath in glob.glob(os.path.join(path, '*.txt')):
    if('spmsga' in filePath):
        mail.openFile('spam', filePath)
    else:
        mail.openFile('ham', filePath)
    wordDict.update(mail)
    
mi = mutualInformation(wordDict.hamCount, wordDict.spamCount)
print('probability of ham: %f' %mi.probHam)
print('probability of spam: %f' %mi.probSpam)
# calculate probability of a word
words = wordDict.words
# tempWord = words[0]
mi.probOfWord(words)
for word in mi.words:
    print(word)
# Out:
# probability of ham: 0.833910
# probability of spam: 0.166090
# ['consider', 4.640268676618842e-05]
# ['entity', 4.640268676618843e-06]
# ['logic-based', 4.640268676618843e-06]
# ['chaim', 4.640268676618843e-06]
# ['25', -7.692528319345243e-05]
# ['interesting', 9.744564220899569e-05]
# [',', 2.8121013237382853e-05]
# ['late', 3.7839358534859626e-05]
# ['to', -8.5783346275904e-05]
# ['mcnamara', 4.640268676618843e-06]
# ['semantics', 6.960403014928259e-05]
# ['has', 0.00010698464547168667]
# ['might', 8.007436849543891e-05]
# ['<', 8.691346241300447e-05]
# ['@', 0.0001845080643638667]
# ['tautologous', 4.640268676618843e-06]
# ['very', -8.660456830758613e-05]
# ['now', -0.00023393761658533626]
# ['vm1', 4.640268676618843e-06]
# ['name', -0.00026063663962614547]
# ['level', 1.9397118419647027e-05]
# ['reduplication', 9.280537353237686e-06]
# ['list', -0.00018575854441223107]
# ['either', 2.7479637481715628e-05]
# ['queries', 6.03234927960449e-05]
# ['zadrozny', 4.640268676618843e-06]
# ['michael', 9.744564220899569e-05]
# ['related', 1.1549075463916651e-05]
# ['second', 0.00012766728983554484]
# ['subject', -0.0001365086204716528]
# ['02', 9.280537353237686e-06]
# ['what', 1.8456165630536888e-05]
# ['est', 1.856107470647537e-05]
# ["'", 2.1793713427398686e-05]
# ['sun', 1.856107470647537e-05]
# ['re', 7.510439513528042e-05]
# ['mmorse', 4.640268676618843e-06]
# ['supplies', -1.0997545581093729e-05]
# ['?', -7.270860666500943e-05]
# ['be', -8.853857570987413e-05]
# ['we', -0.0002033802021915341]
# ['yorku', 9.280537353237686e-06]
# ['here', -0.00014093666501107868]
# ['shmendrik', 4.640268676618843e-06]
# ['by', -8.755072964428877e-05]
# ['on', -4.380177055390735e-05]
# ['about', 2.2133314539555805e-05]
# ['would', 0.00010991854992686251]
# ['anything', -2.5868393027675482e-05]
# ['of', 5.925922509950819e-05]
# ['discussed', 4.640268676618842e-05]
# ['s', -0.00020335031183098056]
# ['(', 0.00026235216215750665]
# ['relevant', 6.960403014928259e-05]
# ['followed', -7.15181360767108e-06]
# ['ca', -6.926634973208238e-05]
# ['logical', 2.320134338309421e-05]
# ['"', -8.740269919752201e-05]
# ['from', -0.00011291327333575318]
# ['asks', 1.856107470647537e-05]
# ['support', -8.737051114745783e-05]
# ['there', 7.342516357219627e-05]
# ['been', 4.2640550598102666e-05]
# ['.', -2.7926069415034e-06]
# ['2', -0.00021544906066421512]
# ['john', 9.280537353237684e-05]
# ['>', -4.348635242366033e-06]
# ['form', -0.00011088218214100527]
# ['that', -1.841932238012871e-06]
# ['wlodek', 4.640268676618843e-06]
# ['construction', 3.248188073633187e-05]
# ['91', -1.0997545581093729e-05]
# ['Subject:', 9.747874759482135e-07]
# ['irrelevant', 1.3920806029856526e-05]
# ['those', -4.126472032104019e-05]
# [':', -6.688607426972272e-05]
# ['15', -0.00011299736838741763]
# ['language', 0.0005150698231046911]
# ['this', -0.00012856401611359216]
# ['864', 4.640268676618843e-06]
# ['value', -5.498772790546864e-05]
# ['were', 7.220885797684987e-06]
# ['dec', -1.0997545581093729e-05]
# ['say', 3.606715629181587e-05]
# ['and', -1.400890129631989e-05]
# ['882', 9.280537353237686e-06]
# ['false', 1.856107470647537e-05]
# ['give', -0.0001531175956060783]
# ['attribute', 4.640268676618843e-06]
# ['is', 4.41966270877927e-05]
# ['in', 0.00011058511812265823]
# ['thus', 4.665691750915015e-05]
# ['it', -7.31685393304432e-05]
# ['an', 1.387422858827256e-05]
# ['as', 0.00011692406110250047]
# ['at', -0.0001738425324775396]
# ['have', -0.00022916330887315535]
# ['sense', 2.823102845902424e-05]
# ['name-attribute', 4.640268676618843e-06]
# ['if', -0.0002304642070483536]
# ['no', -0.0001798497538682142]
# [')', 0.00020406395726401644]
# ['-', -0.0001033293093931066]
# ['indistinguishable', 4.640268676618843e-06]
# ['which', 0.0001657916119200893]
# ['np', 2.7841612059713052e-05]
# ['who', 0.00018002185798462756]
# ['much', -0.00018851815010344057]
# ['said', 3.668919274014389e-05]
# ['date', -0.00014322846637121142]
# ['a', -2.554938265630761e-06]
# ['natural', 6.893392727483878e-05]
# ['for', -0.0001261368495355155]
# ['tautology', 4.640268676618843e-06]
# ['well', -4.126472032104019e-05]
# ['the', -6.496420589755555e-06]
# ['fact', -2.617193517422392e-05]
# ['cute', 4.640268676618843e-06]
# ['illinois', 3.248188073633187e-05]
# ['follows', 2.0477299443642392e-05]
# ['bitnet', 7.888456750252032e-05]
# ['some', 0.000167229129614142]
# ['years', -0.00019837731796674643]
# ['down', -0.00010997545581093728]
# ['ga5123', 4.640268676618843e-06]
# ['colon', 4.640268676618843e-06]
# ['il', 2.7841612059713052e-05]
# ['critique', 2.320134338309421e-05]
# ['tersely', 4.640268676618843e-06]
# ['one', -6.12413795117657e-05]
# ['style', 3.248188073633187e-05]
# ['unique', 1.3920806029856526e-05]
# ['department', 0.00025521477721403616]
# ['discussion', 0.00014848859765180297]
# ['writer', 1.856107470647537e-05]
# ['writing', 5.1089080161094015e-05]
# ['languages', 0.0003573006880996506]
# ['source', 2.9101942358888688e-05]
# ['siucvmb', 9.280537353237686e-06]
# ['62901', 4.640268676618843e-06]
# ['overly', 4.640268676618843e-06]
# ['hartman', 9.280537353237686e-06]
# ['was', 0.00014334109610549672]
# ['ago', -2.2622491666807617e-05]
# ["'s", -1.2863480466211117e-05]
# ['lee', -2.4487229121741736e-05]
# ['read', -0.00011028444208461157]
# ['time', -0.0002730172409433056]
# ['southern', 2.0477299443642392e-05]
# ['reminds', 4.640268676618843e-06]
# ['put', -0.00012096686109871454]
# ['tendencies', 4.640268676618843e-06]
# ['me', 9.467749376645051e-05]
# ['carbondale', 9.280537353237686e-06]
# ['most', -0.00013253021778079603]
# ['i', 0.00018498765976628157]
# ['university', 0.000416670889818641]
# ['favorite', -1.9790385637737813e-05]
# ['foreign', -3.1667907387010676e-05]
# ['item', -7.15181360767108e-06]
# ['u', -4.449477529568994e-05]
# ['forgotten', 9.280537353237686e-06]
# ['found', -7.864438064066983e-06]
# ['+', -5.132570955123297e-05]
# ['newsmagazines', 4.640268676618843e-06]
# ['pro', 9.280537353237686e-06]
# ['over-restriction', 4.640268676618843e-06]
# ['more', -0.00010442348739415631]
# ['quite', 9.744564220899569e-05]
# ['restrictive', 9.280537353237686e-06]
# ['than', 1.0831328696527738e-05]
# ['all', -0.00015060040293222855]
# ['venice', -1.0997545581093729e-05]
# ['paris', -3.7704152778012527e-06]
# ['participants', 7.889791147204183e-06]
# ['thursday', 9.280537353237686e-06]
# ['literary', 2.7841612059713052e-05]
# ['teaching', 6.691794828474757e-05]
# ['include', -0.00013147544059035046]
# ['sent', -0.00010785737831588819]
# ['every-body', 4.640268676618843e-06]
# ['fax', -4.147456805581378e-05]
# ['confirmation', -9.895192818868906e-06]
# ['vegan', 4.640268676618843e-06]
# ['tue', -1.0997545581093729e-05]
# ['venue', 9.280537353237686e-06]
# ['wednesday', 2.7841612059713052e-05]
# ['standards', 9.280537353237686e-06]
# ['affiliation', 1.3920806029856526e-05]
# ['small', -3.575906803835541e-05]
# ['programme', 3.712214941295074e-05]
# ['tel', 6.960403014928259e-05]
# ['core', 1.856107470647537e-05]
# ['dealing', 3.849691821305527e-06]
# ['direct', -3.9580771275475626e-05]
# ['ochs', 4.640268676618843e-06]
# ['stef', 4.640268676618843e-06]
# ['drinks', 9.280537353237686e-06]
# ['even', -0.00012243614560870868]
# ['aim', 1.3920806029856526e-05]
# ['tuedsday', 4.640268676618843e-06]
# ['antwerp', 9.280537353237686e-06]
# ['525', 4.640268676618843e-06]
# ['international', 1.555242728310218e-05]
# [';', 0.0001382081282815184]
# ['method', 1.2022385430605324e-05]
# ['full', -0.00010897761598747524]
# ['degree', 6.960403014928259e-05]
# ['commercial', -4.2496961265512496e-05]
# ['french', 0.00010208591088561446]
# ['understanding', 2.0477299443642392e-05]
# ['hours', -0.00010952379810234871]
# ['address', -0.00029498763038244316]
# ['900', -2.1995091162187457e-05]
# ['gent', 9.280537353237686e-06]
# ['30', -9.489046045023276e-05]
# ['37', 1.856107470647537e-05]
# ['35', -4.3990182324374915e-05]
# ['social', 2.4044770861210648e-05]
# ['studies', 9.59396722899106e-05]
# ['onwards', 1.3920806029856526e-05]
# ['via', -8.807154246159084e-05]
# ['prefer', -1.9790385637737813e-05]
# ['slembrouck', 4.640268676618843e-06]
# ['1st', -3.163015348341092e-05]
# ['1000', -1.9790385637737813e-05]
# ['use', -0.0001103971431700292]
# ['fee', 2.7841612059713052e-05]
# ['usa', -4.947596409434458e-05]
# ['continuous', 1.3920806029856526e-05]
# ['visit', -5.064979037552395e-05]
# ['only', -0.00018870480265783157]
# ['next', -8.128184228245674e-05]
# ['few', -4.362259520369989e-05]
# ['therefore', 2.0477299443642392e-05]
# ['recommend', 1.856107470647537e-05]
# ['francs', 9.280537353237686e-06]
# ['type', -0.00014322846637121142]
# ['belgian', 4.640268676618843e-06]
# ['door', -3.114490620121673e-05]
# ['sessions', 1.3920806029856526e-05]
# ['train', 1.3920806029856526e-05]
# ['non-member', 4.640268676618843e-06]
# ['arranging', 4.640268676618843e-06]
# ['90', -6.228981240243347e-05]
# ['eurocheques', 4.640268676618843e-06]
# ['92', -3.891394065613945e-06]
# ['95', -9.497655030736888e-05]
# ['must', -0.00012091536860865277]
# ['town', -5.498772790546864e-05]
# ['account', -3.4547248173900795e-05]
# ['1992', 0.00013456779162194634]
# ['hour', -0.00010013431268961171]
# ['quoting', 1.856107470647537e-05]
# ['arrangements', 1.3920806029856526e-05]
# ['can', -0.00023819260282831979]
# ['9th', -7.15181360767108e-06]
# ['meet', -1.9790385637737813e-05]
# ['arrive', 1.3920806029856526e-05]
# ['control', -5.448880799373762e-05]
# ['snacks', 4.640268676618843e-06]
# ['expanding', 9.280537353237686e-06]
# ['230', 4.640268676618843e-06]
# ['dinners', 4.640268676618843e-06]
# ['get', -0.0003300107372289947]
# ['circular', 4.640268676618843e-06]
# ['buildings', 4.640268676618843e-06]
# ['attend', 9.280537353237686e-06]
# ['may', -4.195743332122839e-05]
# ['such', 8.111754211291127e-05]
# ['non-literary', 4.640268676618843e-06]
# ['short', 1.5779582294408366e-05]
# ['third', -1.1030076008454392e-05]
# ['register', 2.320134338309421e-05]
# ['provisional', 1.3920806029856526e-05]
# ['first', -6.340978009981178e-05]
# ['dialogic', 4.640268676618843e-06]
# ['office', -7.70576808440025e-05]
# ['september', 4.640268676618842e-05]
# ['wishing', -3.7704152778012527e-06]
# ['industrial', 9.280537353237686e-06]
# ['including', -7.864438064066983e-06]
# ['looks', 2.7841612059713052e-05]
# ['138', -9.895192818868906e-06]
# ['its', 9.04814864736948e-05]
# ['linguistics', 0.0005243503604579284]
# ['20', -9.314033790306865e-05]
# ['flemish', 4.640268676618843e-06]
# ['complex', 4.176241808956955e-05]
# ['easier', 1.3920806029856526e-05]
# ['coffee', 1.3920806029856526e-05]
# ['evening', -5.9417168968136036e-08]
# ['return', -7.70576808440025e-05]
# ['tourist', 4.640268676618843e-06]
# ['food', -9.895192818868906e-06]
# ['practice', 1.856107470647537e-05]
# ['number', -0.00013538588833073885]
# ['lunch', -5.9417168968136036e-08]
# ['not', -0.00013865193862069928]
# ['hall', 6.496376147266374e-05]
# ['bank', -5.498772790546864e-05]
# ['lacto-vegetarian', 4.640268676618843e-06]
# ['rhetoric', 2.7841612059713052e-05]
# ['good', -0.0001036417445217023]
# ['each', -0.00014965663711269324]
# ['european', 4.176241808956955e-05]
# ['side', 4.176241808956955e-05]
# ['staying', 9.280537353237686e-06]
# ['society', 7.888456750252032e-05]
# ['88', 1.3920806029856526e-05]
# ['89', -9.895192818868906e-06]
# ['our', -0.00027025785522071715]
# ['special', -0.0001280708669874376]
# ['encourage', -3.7704152778012527e-06]
# ['7', -9.314033790306865e-05]
# ['dutch', 2.7841612059713052e-05]
# ['theory', 0.00013456779162194634]
# ['semiotic', 1.3920806029856526e-05]
# ['friday', -5.9417168968136036e-08]
# ['approaches', 3.712214941295074e-05]
# ['members', 7.588736174302246e-06]
# ["o'driscoll", 4.640268676618843e-06]
# ['accommodation', 2.7841612059713052e-05]
# ['pre-booked', 4.640268676618843e-06]
# ['pala9', 4.640268676618843e-06]
# ['days', -0.00013976733131957237]
# ['voor', 4.640268676618843e-06]
# ['david', 7.888456750252032e-05]
# ['flanders', 4.640268676618843e-06]
# ['place', -8.319811258154356e-05]
# ['signature', -5.895025723093776e-05]
# ['overpoort', 4.640268676618843e-06]
# ['narratives', 1.3920806029856526e-05]
# ['*', -0.0002132879412141684]
# ['birch', 9.280537353237686e-06]
# ['reflected', 2.7841612059713052e-05]
# ['stylistics', 9.280537353237686e-06]
# ['textual', 1.856107470647537e-05]
# ['sociolinguistics', 3.248188073633187e-05]
# ['open', -2.9685578456606733e-05]
# ['city', -0.000167004491083731]
# ['given', 6.143189833092728e-05]
# ['activities', 4.640268676618842e-05]
# ['start', -9.766241433390195e-05]
# ['least', 4.0248166709459075e-05]
# ['their', 3.179887081769787e-06]
# ['statement', 4.176241808956955e-05]
# ['tea', 9.280537353237686e-06]
# ['hundred', -9.895192818868906e-06]
# ['final', 2.4772753724756402e-05]
# ['opening', 1.856107470647537e-05]
# ['interests', -1.430362721534216e-05]
# ['relationship', -5.9417168968136036e-08]
# ['hotel', -3.7704152778012527e-06]
# ['specify', -7.15181360767108e-06]
# ['population', 2.7841612059713052e-05]
# ['11', 3.750987925946939e-06]
# ['10', -0.0002649292134154886]
# ['unfortunately', 2.7841612059713052e-05]
# ['17', 3.3458974142373785e-05]
# ['surrounding', 9.280537353237686e-06]
# ['double', 2.320134338309421e-05]
# ['transferred', 4.640268676618843e-06]
# ['aims', 1.856107470647537e-05]
# ['strathclyde', 4.640268676618843e-06]
# ['10th', 1.3920806029856526e-05]
# ['declare', 4.640268676618843e-06]
# ['surname', 9.280537353237686e-06]
# ['north', 1.2022385430605324e-05]
# ['breakfast', -9.895192818868906e-06]
# ['any', -6.526270927854003e-05]
# ['speakers', 0.00013456779162194634]
# ['nights', -3.7704152778012527e-06]
# ['depending', -2.157147566317763e-05]
# ['montgomery', 4.640268676618843e-06]
# ['note', -0.00010167515591549028]
# ['also', -1.614946834036181e-05]
# ['take', -0.00010884712100755797]
# ['performance', -1.1030076008454392e-05]
# ['32-91', 4.640268676618843e-06]
# ['centre', 2.7841612059713052e-05]
# ['post-structuralist', 4.640268676618843e-06]
# ['price', -4.3990182324374915e-05]
# ['multilingual', 1.3920806029856526e-05]
# ['vermeylen', 4.640268676618843e-06]
# ['payment', -7.588381916087614e-05]
# ['390-0959358', 4.640268676618843e-06]
# ['cover', 2.7841612059713052e-05]
# ['universiteit', 1.3920806029856526e-05]
# ['currently', -2.145544082301324e-05]
# ['text', -7.686295247506659e-05]
# ['cheap', 9.280537353237686e-06]
# ['session', -3.163015348341092e-05]
# ['participate', 9.280537353237686e-06]
# ['principal', 1.856107470647537e-05]
# ['busy', 4.640268676618843e-06]
# ['northern', 6.03234927960449e-05]
# ['title', -1.1030076008454392e-05]
# ['should', -2.6838552018947977e-05]
# ['theme', 1.856107470647537e-05]
# ['money', -0.00021182297901477714]
# ['8', -9.489046045023276e-05]
# ['interested', -2.3053958450994495e-05]
# ['viewpoint', 4.640268676618843e-06]
# ['wide', 3.849691821305527e-06]
# ['taalkunde', 4.640268676618843e-06]
# ['coast', 1.3920806029856526e-05]
# ['nearly', 3.248188073633187e-05]
# ['processes', 1.856107470647537e-05]
# ['covering', 4.640268676618843e-06]
# ['morning', 3.712214941295074e-05]
# ['18', 1.5779582294408366e-05]
# ['enclose', -2.947512861546888e-05]
# ['restaurants', -1.0997545581093729e-05]
# ['ardennes', 4.640268676618843e-06]
# ['europe', -5.9417168968136036e-08]
# ['are', -0.00017103752173107463]
# ['11th', 9.280537353237686e-06]
# ['00', -0.00021852522114364516]
# ['07', 4.640268676618843e-06]
# ['08', 4.640268676618843e-06]
# ['09', 1.3920806029856526e-05]
# ['please', -0.0002770653989283295]
# ['sociolinguistic', 4.640268676618843e-06]
# ['cooperation', 1.856107470647537e-05]
# ['between', 9.478183539507622e-05]
# ['reading', -2.860725443068432e-05]
# ['numerous', -1.7273624086950398e-05]
# ['available', -0.00013146686867828512]
# ['keynote', 1.856107470647537e-05]
# ['bruges', 4.640268676618843e-06]
# ['bridges', 9.280537353237686e-06]
# ['attention', -3.1667907387010676e-05]
# ['9000', 4.640268676618843e-06]
# ['swift', 4.640268676618843e-06]
# ['pragmatics', 3.712214941295074e-05]
# ['both', 0.00012231248766979183]
# ['dates', -5.9417168968136036e-08]
# ['last', -7.440743788693275e-05]
# ['restaurant', 4.640268676618843e-06]
# ['residence', 9.280537353237686e-06]
# ['bbru', 4.640268676618843e-06]
# ['cafes', 4.640268676618843e-06]
# ['quiet', 9.280537353237686e-06]
# ['etc', 9.04814864736948e-05]
# ['context', 5.5683224119426104e-05]
# ['vegetarian', 4.640268676618843e-06]
# ['elinor', 4.640268676618843e-06]
# ['b-9000', 4.640268676618843e-06]
# ['jim', 1.856107470647537e-05]
# ['tuesday', -5.9417168968136036e-08]
# ['walk', 1.3920806029856526e-05]
# ['64', 1.856107470647537e-05]
# ['throughout', -5.498772790546864e-05]
# ['bovenschelde', 4.640268676618843e-06]
# ['conference', 3.3458974142373785e-05]
# ['bbl', 4.640268676618843e-06]
# ['hoveniersberg', 4.640268676618843e-06]
# ['fri', 4.640268676618843e-06]
# ['three', 2.342489678322137e-05]
# ['pala92', 4.640268676618843e-06]
# ['eurocheque', 9.280537353237686e-06]
# ['500', -5.895025723093776e-05]
# ['enquiries', 9.280537353237686e-06]
# ['prices', -7.15181360767108e-06]
# ['these', -6.032664444482004e-05]
# ['will', -0.00031642694903253655]
# ['near', -1.7273624086950398e-05]
# ['teachers', 6.03234927960449e-05]
# ['many', -6.012225432246425e-05]
# ['study', 9.59396722899106e-05]
# ['conferences', 2.320134338309421e-05]
# ['itself', 1.622350842258229e-05]
# ['make', -0.0002278820573347292]
# ['fluency', 1.856107470647537e-05]
# ['member', -3.891394065613945e-06]
# ['discourse', 6.03234927960449e-05]
# ['parts', 7.889791147204183e-06]
# ['9', -8.90567353698203e-05]
# ['several', -6.446966717837308e-05]
# ['entitled', -7.15181360767108e-06]
# ['independent', -1.1883433793627207e-07]
# ['literature', 0.00011136644823885221]
# ['cheques', -9.895192818868906e-06]
# ['possible', -8.007824154297586e-06]
# ['pubs', 4.640268676618843e-06]
# ['000', -0.00019486819691829887]
# ['student', 3.19087976709095e-05]
# ['supper', 4.640268676618843e-06]
# ['brussels', -1.0997545581093729e-05]
# ['scholars', 1.856107470647537e-05]
# ['thu', 4.640268676618843e-06]
# ['analysis', 0.00012992752294532748]
# ['contact', -7.346168736522514e-05]
# ['english', 0.0003573006880996506]
# ['traditions', 4.640268676618843e-06]
# ['proposed', -1.8223065087310607e-05]
# ['less', -1.5369305633996435e-05]
# ['scotland', 2.320134338309421e-05]
# ['rooms', -1.9790385637737813e-05]
# ['41', 1.856107470647537e-05]
# ['engelse', 4.640268676618843e-06]
# ['wed', 1.856107470647537e-05]
# ['day', -0.00012096686109871454]
# ['other', 6.722663241437202e-06]
# ['combine', 9.280537353237686e-06]
# ['relevance', 1.856107470647537e-05]
# ['east', 2.7841612059713052e-05]
# ['administrative', 1.856107470647537e-05]
# ['australia', 3.3458974142373785e-05]
# ['around', -5.182087226085115e-05]
# ['couple', 1.622350842258229e-05]
# ['papers', 0.0001067261795622333]
# ['february', 2.7841612059713052e-05]
# ['cultural', 4.176241808956955e-05]
# ['historic', 9.280537353237686e-06]
# ['know', -6.74395025351697e-05]
# ['belgium', 1.856107470647537e-05]
# ['tick', -1.0997545581093729e-05]
# ['meersstraat', 4.640268676618843e-06]
# ['like', -3.502254659052549e-05]
# ['55', -2.157147566317763e-05]
# ['alternatively', 9.280537353237686e-06]
# ['multicultural', 4.640268676618843e-06]
# ['martin', 4.176241808956955e-05]
# ['served', 4.640268676618843e-06]
# ['wind-up', 4.640268676618843e-06]
# ['metres', 9.280537353237686e-06]
# ['pala', 4.640268676618843e-06]
# ['total', -0.00011558652126600376]
# ['/', -0.00021455440823013285]
# ['e-mail', 3.5464978490796795e-06]
# ['critical', 2.320134338309421e-05]
# ['rozier', 4.640268676618843e-06]
# ['murdoch', 4.640268676618843e-06]
# ['payments', -2.157147566317763e-05]
# ['vistas', 4.640268676618843e-06]
# ['bf', 4.640268676618843e-06]
# ['eating', -1.0997545581093729e-05]
# ['medieval', 1.856107470647537e-05]
# ['bb', 4.640268676618843e-06]
# ['300', -5.0067156344805856e-05]
# ['seminarie', 4.640268676618843e-06]
# ['rug', 1.856107470647537e-05]
# ['includes', -5.323981091990493e-05]
# ['_', -0.00021690379202218921]
# ['angeles', -2.9685578456606733e-05]
# ['dinner', -5.9417168968136036e-08]
# ['narratology', 4.640268676618843e-06]
# ['sept', 4.640268676618843e-06]
# ['or', -5.497359983757828e-05]
# ['organizers', 9.280537353237686e-06]
# ['plethora', 4.640268676618843e-06]
# ['communication', 3.712214941295074e-05]
# ['into', -4.8568319184808555e-05]
# ['within', -0.0001764476411207202]
# ['two', 0.00011095490438336267]
# ['appropriate', 5.5683224119426104e-05]
# ['registration', -1.1030076008454392e-05]
# ['amsterdam', 3.849691821305527e-06]
# ['feudal', 4.640268676618843e-06]
# ['arcade', 4.640268676618843e-06]
# ['area', -0.00011484310856411156]
# ['transfer', -1.0997545581093729e-05]
# ['specifically', 2.320134338309421e-05]
# ['los', -1.8223065087310607e-05]
# ['listserv', 2.320134338309421e-05]
# ['registered', -1.9264420211000626e-05]
# ['booked', -1.0997545581093729e-05]
# ['but', 0.00017666303534685364]
# ['payable', -7.70576808440025e-05]
# ['with', -0.00011758651858885215]
# ['made', -3.749247054667106e-05]
# ['arranged', 9.280537353237686e-06]
# ['engllang', 4.640268676618843e-06]
# ['highlight', 9.280537353237686e-06]
# ['nederkouter', 4.640268676618843e-06]
# ['minutes', -2.725957922617559e-05]
# ['ac', 0.00010208591088561446]
# ['600', -7.15181360767108e-06]
# ['single', 3.3458974142373785e-05]
# ['83', 4.640268676618843e-06]
# ['campus', 6.03234927960449e-05]
# ['fill', -3.852884042200125e-05]
# ['dotted', -9.895192818868906e-06]
# ['44', 2.4772753724756402e-05]
# ['45', -7.15181360767108e-06]
# ['envisaged', 4.640268676618843e-06]
# ['field', 9.59396722899106e-05]
# ['book', 3.6104428988424934e-06]
# ['role', 4.176241808956955e-05]
# ['details', -4.712953752586014e-05]
# ['evenings', 4.640268676618843e-06]
# ['you', -0.00041092409512981707]
# ['discours', 4.640268676618843e-06]
# ['problems', 2.4044770861210648e-05]
# ['stay', -3.308855012983172e-05]
# ['cheque', -7.15181360767108e-06]
# ['transfers', 4.640268676618843e-06]
# ['agm', 4.640268676618843e-06]
# ['overlooking', 4.640268676618843e-06]
# ['2000', -7.15181360767108e-06]
# ['compete', -1.9264420211000626e-05]
# ['reception', 1.856107470647537e-05]
# ['oral', -3.2868860147587614e-05]
# ['8th', 1.3920806029856526e-05]
# ['point', 8.447919592939235e-05]
# ['edu', 0.00026025940793719026]
# ['books', -2.145544082301324e-05]
# ['psych', 9.280537353237686e-06]
# ['send', -0.00025304122786728734]
# ['directly', -2.239585058339773e-05]
# ['query', 0.00014848859765180297]
# ['!', -0.0004497053610384021]
# ['constructions', 2.7841612059713052e-05]
# ['causative', 4.640268676618843e-06]
# ['anyone', 8.46930853770727e-05]
# ['korean', 2.7841612059713052e-05]
# ['causatives', 9.280537353237686e-06]
# ['hiromi', 4.640268676618843e-06]
# ['articles', 7.889791147204183e-06]
# ['stanford', 1.3920806029856526e-05]
# ['could', 8.049633341891815e-05]
# ['morikawa', 4.640268676618843e-06]
# ['thanks', 6.847818280630206e-05]
# ['help', -0.0001581507674170546]
# ['seems', 7.567871706971925e-05]
# ['program', -0.00011161115683039913]
# ['40146', 9.280537353237686e-06]
# ['colleague', 1.856107470647537e-05]
# ['aspects', 6.496376147266374e-05]
# ['areas', 7.341825989017384e-05]
# ['school', 0.00010498524471155764]
# ['skills', 3.849691821305527e-06]
# ['patrick', 1.3920806029856526e-05]
# ['shock', -1.0997545581093729e-05]
# ['l2', 9.280537353237686e-06]
# ['references', 0.00010498524471155764]
# ['linguist', 0.00021809262780108542]
# ['summarise', 1.3920806029856526e-05]
# ['people', -0.0001015864889726426]
# ['doing', -4.599916882431647e-05]
# ['culture', 5.104295544280723e-05]
# ['out', -0.00019594980528020401]
# ['wondered', 9.280537353237686e-06]
# ['deeply', 1.3920806029856526e-05]
# ['written', 7.699383642611054e-06]
# ['evaluation', -3.2868860147587614e-05]
# ['participation', -1.9790385637737813e-05]
# ['approached', 9.280537353237686e-06]
# ['exchange', 3.849691821305527e-06]
# ['however', 1.527893321529453e-05]
# ['anthropology', 4.176241808956955e-05]
# ['gratefully', 9.280537353237686e-06]
# ['box', -8.807154246159084e-05]
# ['empathy', 4.640268676618843e-06]
# ['thing', 7.588736174302246e-06]
# ['became', -5.9417168968136036e-08]
# ['due', -3.969142510843447e-06]
# ['involvement', 9.280537353237686e-06]
# ['learning', 5.999093542744103e-05]
# ['prepare', -7.15181360767108e-06]
# ['negative', 3.712214941295074e-05]
# ['dropping', 4.640268676618843e-06]
# ['territory', 1.3920806029856526e-05]
# ['po', -4.314295132635526e-05]
# ['he', 0.00014235022697079144]
# ['casuarina', 4.640268676618843e-06]
# ['acquisition', 9.280537353237684e-05]
# ['received', -1.1674182196841714e-05]
# ['mine', 2.320134338309421e-05]
# ['high', -4.1774568541443284e-05]
# ['seem', 8.816510485575787e-05]
# ['education', 1.9892535359840977e-05]
# ['apparently', 2.7841612059713052e-05]
# ['able', -3.256187887427986e-05]
# ['ideas', 6.960403014928259e-05]
# ['0811', 9.280537353237686e-06]
# ['graduate', 6.960403014928259e-05]
# ['nt', -5.9417168968136036e-08]
# ['development', 6.496376147266374e-05]
# ['immersed', 4.640268676618843e-06]
# ['object', 2.7841612059713052e-05]
# ['northrn', 9.280537353237686e-06]
# ['mcconvell', 9.280537353237686e-06]
# ['indonesia', 1.856107470647537e-05]
# ['correlation', 9.280537353237686e-06]
# ['indebted', 4.640268676618843e-06]
# ['psycholinguistics', 3.248188073633187e-05]
# ['m', 6.75585002350087e-05]
# ['suggestions', 1.2022385430605324e-05]
# ['course', 3.6104428988424934e-06]
# ['undergraduate', 5.5683224119426104e-05]
# ['specific', 1.2022385430605324e-05]
# ['had', 3.4224087529229364e-06]
# ['offer', -0.0001206936940041781]
# ['acquisiton', 4.640268676618843e-06]
# ['deaf', 2.320134338309421e-05]
# ['instructors', 9.280537353237686e-06]
# ['experiences', 1.3920806029856526e-05]
# ['alinguals', 4.640268676618843e-06]
# ['klaiman', 4.640268676618843e-06]
# ['helen', 1.3920806029856526e-05]
# ['asl', 1.856107470647537e-05]
# ['neville', 4.640268676618843e-06]
# ['shortly', 2.7841612059713052e-05]
# ['texts', 9.280537353237684e-05]
# ['work', -0.0001421002786994492]
# ['appreciate', 2.0477299443642392e-05]
# ['umnacux', 4.640268676618843e-06]
# ['ken', 1.3920806029856526e-05]
# ['german', 4.640268676618842e-05]
# ['modern', 0.00013456779162194634]
# ['am', -1.2242050588223439e-05]
# ['parc', 9.280537353237686e-06]
# ['information', -0.000265400413345368]
# ['looking', -8.4336417665858e-05]
# ['on-line', -3.7704152778012527e-06]
# ['beesley', 9.280537353237686e-06]
# ['xerox', 1.3920806029856526e-05]
# ['appreciated', 2.7841612059713052e-05]
# ['corpora', 4.640268676618843e-06]
# ['com', -0.00017890291643804572]
# ['requirement', 1.3920806029856526e-05]
# ['useful', 2.0477299443642392e-05]
# ['library', -1.9790385637737813e-05]
# ['design', 2.320134338309421e-05]
# ['little', -3.972282665895399e-05]
# ['wang', 4.640268676618843e-06]
# ['phonetics', 4.176241808956955e-05]
# ['experiment', 1.3920806029856526e-05]
# ['ed', 2.0477299443642392e-05]
# ['mandarin', 1.856107470647537e-05]
# ['on-going', 9.280537353237686e-06]
# ['do', -0.0002431878132135472]
# ['lot', -1.1466986321410427e-05]
# ['welcome', 4.176241808956955e-05]
# ['hi', 3.849691821305527e-06]
# ['ling', 4.176241808956955e-05]
# ['uk', 5.999093542744103e-05]
# ['debates', 4.640268676618843e-06]
# ['phonology', 9.280537353237684e-05]
# ['part', 1.959390089444975e-05]
# ['t', -4.599916882431647e-05]
# ['tones', 9.280537353237686e-06]
# ['my', 3.814369208195422e-05]
# ['think', 0.00011791214620760184]
# ['sophia', 4.640268676618843e-06]
# ['one-year', 9.280537353237686e-06]
# ['213', 1.856107470647537e-05]
# ['candidates', 7.889791147204183e-06]
# ['lake', 1.3920806029856526e-05]
# ['propose', 1.856107470647537e-05]
# ['utah', 1.3920806029856526e-05]
# ['they', -7.498494109334212e-05]
# ['d', 8.007436849543891e-05]
# ['courses', 7.888456750252032e-05]
# ['reference', 0.00010208591088561446]
# ['further', -4.070162342571031e-05]
# ['majors', 9.280537353237686e-06]
# ['visiting', 9.280537353237686e-06]
# ['7432', 4.640268676618843e-06]
# ['email', -0.0002521609314646451]
# ['publications', 1.2022385430605324e-05]
# ['mauricio', 9.280537353237686e-06]
# ['801-581', 4.640268676618843e-06]
# ['job', -6.182946316052567e-05]
# ['teach', -5.9371156913213466e-05]
# ['introductory', 1.3920806029856526e-05]
# ['american', -5.4669195261931815e-05]
# ['stewart', 9.280537353237686e-06]
# ['letters', -2.860725443068432e-05]
# ['anthro', 1.3920806029856526e-05]
# ['84112', 4.640268676618843e-06]
# ['expected', 2.320134338309421e-05]
# ['dipaolo', 4.640268676618843e-06]
# ['curriculum', 4.176241808956955e-05]
# ['general', 0.00011351807560457905]
# ['b', -2.970858448407886e-07]
# ['ut', 9.280537353237686e-06]
# ['mixco', 4.640268676618843e-06]
# ['telephone', -4.314295132635526e-05]
# ['sample', -5.323981091990493e-05]
# ['minimum', -3.299263674328119e-05]
# ['application', -2.539662224316065e-05]
# ['assistant', 3.248188073633187e-05]
# ['vitae', 2.7841612059713052e-05]
# ['begin', -4.403577123079542e-05]
# ['director', -5.9417168968136036e-08]
# ['applications', 1.1712448391610685e-05]
# ['letter', -5.9371156913213466e-05]
# ['building', 1.2022385430605324e-05]
# ['professor', 6.496376147266374e-05]
# ['invites', 1.3920806029856526e-05]
# ['position', 2.3669373441612628e-05]
# ['salt', 4.640268676618843e-06]
# ['3p8', 4.640268676618843e-06]
# ['signe', 4.640268676618843e-06]
# ['enseignement', 4.640268676618843e-06]
# ['exigences', 9.280537353237686e-06]
# ['papen', 4.640268676618843e-06]
# ['le', 1.3920806029856526e-05]
# ['la', 2.9101942358888688e-05]
# ['communaute', 4.640268676618843e-06]
# ['c', -5.132570955123297e-05]
# ['regulier', 4.640268676618843e-06]
# ['avan', 9.280537353237686e-06]
# ['aux', 1.3920806029856526e-05]
# ['nom', 4.640268676618843e-06]
# ['formement', 4.640268676618843e-06]
# ['de', 0.00013920806029856517]
# ['acces', 4.640268676618843e-06]
# ['interesses', 4.640268676618843e-06]
# ['sont', 9.280537353237686e-06]
# ['faire', 4.640268676618843e-06]
# ['collective', 2.320134338309421e-05]
# ['l', 7.501975851893878e-06]
# ['citoyens-es', 4.640268676618843e-06]
# ['p', -1.5244720434093011e-05]
# ['poste', 9.280537353237686e-06]
# ['etudes', 9.280537353237686e-06]
# ['en', 2.7841612059713052e-05]
# ['quebec', 1.856107470647537e-05]
# ['4652', 4.640268676618843e-06]
# ['incluant', 4.640268676618843e-06]
# ['et', 4.640268676618842e-05]
# ['fonction', 4.640268676618843e-06]
# ['canada', 5.104295544280723e-05]
# ['8888', 4.640268676618843e-06]
# ['robert', 1.2022385430605324e-05]
# ['juillet', 9.280537353237686e-06]
# ['profil', 4.640268676618843e-06]
# ['femmes', 9.280537353237686e-06]
# ['priees', 4.640268676618843e-06]
# ['jury', 9.280537353237686e-06]
# ['temps', 4.640268676618843e-06]
# ['les', 2.320134338309421e-05]
# ['vitalite', 4.640268676618843e-06]
# ['selon', 4.640268676618843e-06]
# ['assurer', 4.640268676618843e-06]
# ['egalite', 4.640268676618843e-06]
# ['repondants', 4.640268676618843e-06]
# ['candidatures', 9.280537353237686e-06]
# ['domaine', 9.280537353237686e-06]
# ['recentes', 4.640268676618843e-06]
# ['recherche', 9.280537353237686e-06]
# ['une', 3.248188073633187e-05]
# ['montreal', 4.640268676618843e-06]
# ['con', -3.7704152778012527e-06]
# ['departement', 9.280537353237686e-06]
# ['ce', 9.280537353237686e-06]
# ['services', -5.0067156344805856e-05]
# ['phonologie', 9.280537353237686e-06]
# ['fert', 4.640268676618843e-06]
# ['traitement', 4.640268676618843e-06]
# ['directeur', 4.640268676618843e-06]
# ['avec', 9.280537353237686e-06]
# ['attestant', 4.640268676618843e-06]
# ['convention', 1.856107470647537e-05]
# ['fonctions', 4.640268676618843e-06]
# ['ph', 2.9101942358888688e-05]
# ['permanentes-es', 4.640268676618843e-06]
# ['linguistique', 1.3920806029856526e-05]
# ['adresse', 9.280537353237686e-06]
# ['immigration', -9.895192818868906e-06]
# ['revues', 4.640268676618843e-06]
# ['1er', 1.3920806029856526e-05]
# ['sollicite', 4.640268676618843e-06]
# ['e', -3.8423264084990835e-05]
# ['emploi', 9.280537353237686e-06]
# ['dossier', 9.280537353237686e-06]
# ['professeur', 9.280537353237686e-06]
# ['des', 2.320134338309421e-05]
# ['dans', 1.856107470647537e-05]
# ['pour', 1.3920806029856526e-05]
# ['ere', 4.640268676618843e-06]
# ['un', 3.712214941295074e-05]
# ['cees', 4.640268676618843e-06]
# ['trois', 9.280537353237686e-06]
# ['encadrement', 4.640268676618843e-06]
# ['h3c', 4.640268676618843e-06]
# ['premier', -1.9264420211000626e-05]
# ['avant', 9.280537353237686e-06]
# ['au', 4.640268676618842e-05]
# ['experience', 1.1337209109662437e-05]
# ['specialite', 4.640268676618843e-06]
# ['mai', 4.640268676618843e-06]
# ['uqam', 4.640268676618843e-06]
# ['telecopieur', 9.280537353237686e-06]
# ['relatives', -1.9790385637737813e-05]
# ['personnes', 4.640268676618843e-06]
# ['universitaire', 4.640268676618843e-06]
# ['competence', 3.248188073633187e-05]
# ['complet', 4.640268676618843e-06]
# ['spuq-uqam', 4.640268676618843e-06]
# ['entree', 9.280537353237686e-06]
# ['numero', 4.640268676618843e-06]
# ['succ', 4.640268676618843e-06]
# ['residents-es', 4.640268676618843e-06]
# ['vise', 4.640268676618843e-06]
# ['8416', 4.640268676618843e-06]
# ['parvenir', 4.640268676618843e-06]
# ['cycle', 4.640268676618843e-06]
# ['solide', 4.640268676618843e-06]
# ['souscrit', 4.640268676618843e-06]
# ['francais', 9.280537353237686e-06]
# ['514-987', 4.640268676618843e-06]
# ['r14730', 4.640268676618843e-06]
# ['focus', 5.104295544280723e-05]
# ['syntax', 0.000143848328975184]
# ['tenable', 4.640268676618843e-06]
# ['3hp', 4.640268676618843e-06]
# ['candidate', -1.1030076008454392e-05]
# ['kingdom', 9.280537353237686e-06]
# ['advantage', -1.1030076008454392e-05]
# ['october', 3.248188073633187e-05]
# ['pounds', -7.15181360767108e-06]
# ['h', 3.7839358534859626e-05]
# ['a083', 4.640268676618843e-06]
# ['827', 4.640268676618843e-06]
# ['old', -3.575906803835541e-05]
# ['dissertation', 4.176241808956955e-05]
# ['scale', -3.7704152778012527e-06]
# ['lectureship', 9.280537353237686e-06]
# ['per', -0.0001738827719488108]
# ['research', 0.00014683651978034768]
# ['officer', 9.280537353237686e-06]
# ['ability', -1.1883433793627207e-07]
# ['strong', -1.1883433793627207e-07]
# ['obtained', 1.3920806029856526e-05]
# ['g', 0.00010217816032218803]
# ['completing', 4.640268676618843e-06]
# ['according', -7.540830555602505e-06]
# ['o', -1.1466986321410427e-05]
# ['range', 1.2022385430605324e-05]
# ['published', 0.0001206469855920898]
# ['grade', 2.320134338309421e-05]
# ['durham', 4.640268676618843e-06]
# ['generative', 5.5683224119426104e-05]
# ['post', -3.1667907387010676e-05]
# ['3158', 4.640268676618843e-06]
# ['4747', 4.640268676618843e-06]
# ['whom', 2.320134338309421e-05]
# ['successful', -1.430362721534216e-05]
# ['completed', 7.889791147204183e-06]
# ['f', 2.823102845902424e-05]
# ['091-374', 4.640268676618843e-06]
# ['860', 9.280537353237686e-06]
# ['n', -3.309022802536323e-05]
# ['r', -2.3766867587254414e-07]
# ['historical', 4.176241808956955e-05]
# ['v', 3.7839358534859626e-05]
# ['demonstrate', 1.856107470647537e-05]
# ['doctorate', 1.3920806029856526e-05]
# ['process', -5.323981091990493e-05]
# ['romance', 2.320134338309421e-05]
# ['united', -6.598527348656238e-05]
# ['personnel', 9.280537353237686e-06]
# ['1', -0.00017268143934226992]
# ['shire', 4.640268676618843e-06]
# ['=', -6.747238971267589e-05]
# ['lecturer', 1.3920806029856526e-05]
# ['quote', 2.320134338309421e-05]
# ['salary', 4.176241808956955e-05]
# ['annum', 9.280537353237686e-06]
# ['later', -1.1311245833403808e-05]
# ['y', 5.1089080161094015e-05]
# ['12', -8.90567353698203e-05]
# ['dh1', 4.640268676618843e-06]
# ['natively', 4.640268676618843e-06]
# ['concord', 1.3920806029856526e-05]
# ['back', -0.00012096686109871454]
# ['grammaticality', 1.856107470647537e-05]
# ['kroch', 4.640268676618843e-06]
# ['questions', -5.40380713124179e-05]
# ['dialects', 6.03234927960449e-05]
# ['ll', -8.67672660991584e-05]
# ['various', 5.8203884717777376e-05]
# ['answer', -3.1667907387010676e-05]
# ['speaks', 3.712214941295074e-05]
# ['dialect', 6.496376147266374e-05]
# ['them', -0.000168672835331716]
# ['effect', 3.712214941295074e-05]
# ['willing', 1.2022385430605324e-05]
# ['change', 7.699383642611054e-06]
# ['grammar', 0.00013456779162194634]
# ['british', 4.640268676618842e-05]
# ['upenn', 1.3920806029856526e-05]
# ['uses', -3.891394065613945e-06]
# ['spanish', 6.496376147266374e-05]
# ['translation', 6.03234927960449e-05]
# ['thank', -3.6446130174621214e-05]
# ['wojcik', 9.280537353237686e-06]
# ['rick', 2.7841612059713052e-05]
# ['responses', 1.1549075463916651e-05]
# ['shelf', -9.895192818868906e-06]
# ['commercially', 9.280537353237686e-06]
# ['trying', 1.2022385430605324e-05]
# ['rwojcik', 4.640268676618843e-06]
# ['projects', 3.248188073633187e-05]
# ['boeing', 4.640268676618843e-06]
# ['atc', 4.640268676618843e-06]
# ['programs', -0.00011850241770951719]
# ['summary', 0.00010208591088561446]
# ['compile', -3.7704152778012527e-06]
# ['aid', 2.7841612059713052e-05]
# ['software', -7.482831855634662e-05]
# ['addresses', -0.00011301636903428314]
# ['julie', 4.640268676618843e-06]
# ['gunnar', 4.640268676618843e-06]
# ['jules', 9.280537353237686e-06]
# ['does', 4.648752375415183e-05]
# ['fant', 4.640268676618843e-06]
# ['christol', 4.640268676618843e-06]
# ['silverman', 4.640268676618843e-06]
# ['advance', 2.9101942358888688e-05]
# ['nynexst', 4.640268676618843e-06]
# ['gobl', 4.640268676618843e-06]
# ['anybody', 1.5779582294408366e-05]
# ['irish', 9.280537353237686e-06]
# ['garnet', 9.280537353237686e-06]
# ['hard', -3.256187887427986e-05]
# ['sources', -1.1883433793627207e-07]
# ['laurel', -1.0997545581093729e-05]
# ['sutton', 9.280537353237686e-06]
# ['working', -7.346168736522514e-05]
# ['palatal', 9.280537353237686e-06]
# ['too', -6.909449634780159e-05]
# ['finding', -3.7704152778012527e-06]
# ['postings', 3.248188073633187e-05]
# ['consonants', 1.856107470647537e-05]
# ['berkeley', 5.104295544280723e-05]
# ['helpful', 1.856107470647537e-05]
# ['slender', 4.640268676618843e-06]
# ['project', 4.223959796469618e-05]
# ['so', 6.203754267594342e-05]
# ['having', -7.864438064066983e-06]
# ['through', -1.9020087119151863e-05]
# ['yet', -3.8836443755186845e-05]
# ['icelandic', 4.640268676618843e-06]
# ['fix', -1.0997545581093729e-05]
# ['borrowed', 4.640268676618843e-06]
# ['uconnvm', 9.280537353237686e-06]
# ['reply', -8.830973780516287e-05]
# ['series', 1.2022385430605324e-05]
# ['phenomena', 6.03234927960449e-05]
# ['see', -0.00016639622516308712]
# ['kinds', 5.5683224119426104e-05]
# ['laurencot', 4.640268676618843e-06]
# ['movie', 9.280537353237686e-06]
# ['ellipsis', 4.640268676618843e-06]
# ['laurenco', 4.640268676618843e-06]
# ['tell', -6.182946316052567e-05]
# ['wants', -3.891394065613945e-06]
# ['volume', -2.725957922617559e-05]
# ['connecticut', 4.640268676618843e-06]
# ['whether', 0.00011858409802780904]
# ['car', -3.852884042200125e-05]
# ['bill', -9.897791022984358e-05]
# ['mary', 3.849691821305527e-06]
# ["n't", -0.00011200856313392732]
# ['want', -0.00018765291926563257]
# ['vp', 4.640268676618843e-06]
# ['something', -1.1466986321410427e-05]
# ['check', -0.00014332157972250532]
# ['suggest', 4.176241808956955e-05]
# ['how', -0.00022067172419300044]
# ['elizabeth', 2.320134338309421e-05]
# ['because', 2.3098150927833302e-05]
# ['queen', 9.280537353237686e-06]
# ['pcs', 9.280537353237686e-06]
# ['whereabout', 4.640268676618843e-06]
# ['computer', -4.599916882431647e-05]
# ['college', 5.553425724553756e-05]
# ['need', -0.00017247029415901752]
# ['peter', 1.856107470647537e-05]
# ['along', -7.684652816998218e-06]
# ['hawkins', 9.280537353237686e-06]
# ['micros', 4.640268676618843e-06]
# ['collaborated', 4.640268676618843e-06]
# ['edinburgh', 2.320134338309421e-05]
# ['self-instructional', 4.640268676618843e-06]
# ['notation', 1.856107470647537e-05]
# ['seeking', -4.159905629077178e-05]
# ['moved', 1.856107470647537e-05]
# ['dr', 5.1089080161094015e-05]
# ['him', 7.588736174302246e-06]
# ['search', -4.159905629077178e-05]
# ['ibm', -3.7704152778012527e-06]
# ['phonetic', 3.248188073633187e-05]
# ['phonetician', 4.640268676618843e-06]
# ['words', 3.9785070719681955e-05]
# ['toby', 4.640268676618843e-06]
# ['trivial', 1.3920806029856526e-05]
# ['cornell', 2.320134338309421e-05]
# ['passive', -7.15181360767108e-06]
# ['folks', 1.3920806029856526e-05]
# ['paff', 4.640268676618843e-06]
# ['colleagues', 6.03234927960449e-05]
# ['verb', 6.496376147266374e-05]
# ['particle', 4.640268676618843e-06]
# ['378', 4.640268676618843e-06]
# ['often', 5.553425724553756e-05]
# ['absolutely', -1.7273624086950398e-05]
# ['telnetting', 4.640268676618843e-06]
# ['intransitively', 4.640268676618843e-06]
# ['3', -9.336032657004415e-05]
# ['new', -0.000168672835331716]
# ['told', 4.640268676618842e-05]
# ['never', -8.67672660991584e-05]
# ['although', 6.893392727483878e-05]
# ['ordinary', 4.640268676618843e-06]
# ['actual', -3.7704152778012527e-06]
# ['correctness', 1.3920806029856526e-05]
# ['hence', 1.3920806029856526e-05]
# ['transitive', 9.280537353237686e-06]
# ['pucc', 9.280537353237686e-06]
# ['feelings', 9.280537353237686e-06]
# ['rarely', 2.320134338309421e-05]
# ['acquire', 2.320134338309421e-05]
# ['telnet', 4.640268676618843e-06]
# ['cuny', 4.640268676618843e-06]
# ['hear', -6.182946316052567e-05]
# ['myself', 1.5779582294408366e-05]
# ['princeton', 1.3920806029856526e-05]
# ['characteristics', 1.856107470647537e-05]
# ['heard', -1.4831591765230006e-05]
# ['spends', 4.640268676618843e-06]
# ['realm', 9.280537353237686e-06]
# ['syntactic', 6.03234927960449e-05]
# ['tobypaff', 4.640268676618843e-06]
# ['cunyvm', 4.640268676618843e-06]
# ['inquiry', 1.3920806029856526e-05]
# ['used', 1.91263771683691e-05]
# ['curiosity', 4.640268676618843e-06]
# ['why', -0.0001008297775790796]
# ['command', 2.320134338309421e-05]
# ['nagata', 4.640268676618843e-06]
# ['grammatical', 6.496376147266374e-05]
# ['intuition', 9.280537353237686e-06]
# ['hiroshi', 4.640268676618843e-06]
# ['judgements', -7.15181360767108e-06]
# ['concludes', 4.640268676618843e-06]
# ['relative', 1.2022385430605324e-05]
# ['1-17', 4.640268676618843e-06]
# ['intuitions', 4.640268676618843e-06]
# ['taiwan', 1.3920806029856526e-05]
# ['absolute', -9.895192818868906e-06]
# ['influenced', 2.320134338309421e-05]
# ['&', -0.00010217498544234462]
# ['relativity', 9.280537353237686e-06]
# ['maps', 9.280537353237686e-06]
# ['jane', 1.856107470647537e-05]
# ['linguistic', 0.00023665370250756078]
# ['variables', 9.280537353237686e-06]
# ['resources', -7.540830555602505e-06]
# ['sinica', 4.640268676618843e-06]
# ['though', 8.691346241300447e-05]
# ['easily', -2.725957922617559e-05]
# ['journal', 4.223959796469618e-05]
# ['lapolla', 4.640268676618843e-06]
# ['losing', -1.0997545581093729e-05]
# ['repetition', 4.640268676618843e-06]
# ['revealed', 9.280537353237686e-06]
# ['linguists', 0.00020881209044784773]
# ['tang', 9.280537353237686e-06]
# ['psycholinguistic', 4.640268676618843e-06]
# ['philology', 4.640268676618843e-06]
# ['institute', 5.104295544280723e-05]
# ['randy', 9.280537353237686e-06]
# ['embedded', 4.640268676618843e-06]
# ['370', 4.640268676618843e-06]
# ['academia', 9.280537353237686e-06]
# ['history', 4.0954598887284783e-05]
# ['mentioned', 5.1089080161094015e-05]
# ['contributions', 2.7841612059713052e-05]
# ['line', -0.0001200446195541084]
# ['announcement', 3.248188073633187e-05]
# ['bibliography', 2.7841612059713052e-05]
# ['bib', 4.640268676618843e-06]
# ['highly', -1.4831591765230006e-05]
# ['complete', -0.00014069472452462185]
# ['apologies', 4.640268676618843e-06]
# ['server', -3.163015348341092e-05]
# ['power', -7.588381916087614e-05]
# ['inappropriate', 9.280537353237686e-06]
# ['unable', -1.7273624086950398e-05]
# ['internet', -0.0001441744672554901]
# ['tamvm1', 4.640268676618843e-06]
# ['respondents', -3.7704152778012527e-06]
# ['[', 3.484025914333392e-06]
# ['receive', -0.00017871251868108087]
# ['relate', 1.3920806029856526e-05]
# ['another', 3.566154849056244e-05]
# ['message', -0.00013147544059035046]
# ['combines', 4.640268676618843e-06]
# ['listed', -1.1030076008454392e-05]
# ['theoretical', 0.00011600671691547097]
# ['tamu', 4.640268676618843e-06]
# ['particularistic', 4.640268676618843e-06]
# ['posting', 3.3458974142373785e-05]
# ['applied', 5.3867076635501484e-05]
# ['consist', 1.856107470647537e-05]
# ['placed', -7.15181360767108e-06]
# ['while', -1.1674182196841714e-05]
# ['items', -1.9790385637737813e-05]
# ['then', -0.00020428493497596983]
# ['topic', 2.9101942358888688e-05]
# ['file', -5.448880799373762e-05]
# ['incorrect', 2.320134338309421e-05]
# ['verify', 9.280537353237686e-06]
# ['moderators', 9.280537353237686e-06]
# ['3-366', 4.640268676618843e-06]
# [']', 3.484025914333392e-06]
# ['incomplete', 1.3920806029856526e-05]
# ['el', 1.856107470647537e-05]
# ['ciudad', 9.280537353237686e-06]
# ['texas', -7.540830555602505e-06]
# ['busco', 4.640268676618843e-06]
# ['es', -1.7273624086950398e-05]
# ['condados', 4.640268676618843e-06]
# ['iaupe', 4.640268676618843e-06]
# ['informacion', 4.640268676618843e-06]
# ['hay', 4.640268676618843e-06]
# ['sobre', 1.856107470647537e-05]
# ['alguien', 4.640268676618843e-06]
# ['programa', 9.280537353237686e-06]
# ['brett', 1.3920806029856526e-05]
# ['comunicar', 4.640268676618843e-06]
# ['distintos', 4.640268676618843e-06]
# ['que', 2.320134338309421e-05]
# ['puede', 4.640268676618843e-06]
# ['como', 9.280537353237686e-06]
# ['ordenadores', 4.640268676618843e-06]
# ['forman', 4.640268676618843e-06]
# ['limitrofes', 4.640268676618843e-06]
# ['gracias', 4.640268676618843e-06]
# ['educacion', 9.280537353237686e-06]
# ['sepa', 4.640268676618843e-06]
# ['bilingue', 9.280537353237686e-06]
# ['universidad', 1.3920806029856526e-05]
# ['376', 4.640268676618843e-06]
# ['austin', 3.712214941295074e-05]
# ['se', 1.622350842258229e-05]
# ['particularly', 7.888456750252032e-05]
# ['results', -4.454918263065475e-05]
# ['community', 1.622350842258229e-05]
# ['slab', 4.640268676618843e-06]
# ['find', -9.075382818219554e-05]
# ['indicate', 1.856107470647537e-05]
# ['turbo', 4.640268676618843e-06]
# ['cube', 4.640268676618843e-06]
# ['whatever', 4.640268676618842e-05]
# ['using', -7.181290606868816e-05]
# ['model', 4.640268676618842e-05]
# ['workstation', 4.640268676618843e-06]
# ['attempt', 5.104295544280723e-05]
# ['your', -0.00042496961265512496]
# ['survey', 1.856107470647537e-05]
# ['function', 2.7841612059713052e-05]
# ['own', -0.0001229170313833947]
# ['pragmatic', 1.856107470647537e-05]
# ['interrogatives', 4.640268676618843e-06]
# ['replies', -1.1883433793627207e-07]
# ['state', -0.00018598868272928171]
# ['freed', 4.640268676618843e-06]
# ['correspondence', 1.3920806029856526e-05]
# ['familiar', 1.622350842258229e-05]
# ['montclair', 9.280537353237686e-06]
# ['apollo', 1.3920806029856526e-05]
# ['discuss', 2.7841612059713052e-05]
# ['alice', 9.280537353237686e-06]
# ['suggests', 2.320134338309421e-05]
# ['claims', 2.7841612059713052e-05]
# ['otherwise', -2.725957922617559e-05]
# ['steve', 1.856107470647537e-05]
# ['facts', 2.320134338309421e-05]
# ['pedro', 9.280537353237686e-06]
# ['violate', 2.320134338309421e-05]
# ['hablo', 4.640268676618843e-06]
# ['local', -2.145544082301324e-05]
# ['informants', 2.320134338309421e-05]
# ['cases', 1.1549075463916651e-05]
# ['domain', -1.9790385637737813e-05]
# ['pronoun', 1.856107470647537e-05]
# ['violated', 1.3920806029856526e-05]
# ['principles', 6.496376147266374e-05]
# ['examples', 7.791006356385298e-05]
# ['provided', 2.0477299443642392e-05]
# ['since', 8.730582707666607e-05]
# ['anaphor', 4.640268676618843e-06]
# ['recently', 6.03234927960449e-05]
# ['free', -0.00020994155848761426]
# ['greatly', 1.856107470647537e-05]
# ['bound', 1.856107470647537e-05]
# ['insist', 9.280537353237686e-06]
# ['interest', 3.484025914333392e-06]
# ['binding', -5.9417168968136036e-08]
# ['apparent', 9.280537353237686e-06]
# ['particular', 9.280537353237684e-05]
# ['problem', -1.15803065052685e-05]
# ['seegmiller', 4.640268676618843e-06]
# ['clearly', 1.555242728310218e-05]
# ['stumbled', -1.0997545581093729e-05]
# ['perhaps', 5.1089080161094015e-05]
# ['juan', 2.320134338309421e-05]
# ['upon', -5.15362195783672e-05]
# ['data', 0.00013221343471790577]
# ['thoughts', 1.856107470647537e-05]
# ['antecedent', 4.640268676618843e-06]
# ['maybe', -1.1311245833403808e-05]
# ['clear', -2.9260662207555095e-05]
# ['request', -1.8223065087310607e-05]
# ['principle', 3.248188073633187e-05]
# ['summer', 7.889791147204183e-06]
# ['madison', 4.640268676618843e-06]
# ['torres', 4.640268676618843e-06]
# ['represent', -2.725957922617559e-05]
# ['thomas', -1.7273624086950398e-05]
# ['jean', 1.3920806029856526e-05]
# ['bring', 2.7841612059713052e-05]
# ['scholarly', 1.3920806029856526e-05]
# ['fueros', 4.640268676618843e-06]
# ['disk', -9.895192818868906e-06]
# ['quincentenary', 4.640268676618843e-06]
# ['meditationes', 4.640268676618843e-06]
# ['27', 7.889791147204183e-06]
# ['group', 2.4044770861210648e-05]
# ['indica', 4.640268676618843e-06]
# ['han', 4.640268676618843e-06]
# ['realmente', 4.640268676618843e-06]
# ['imitatio', 4.640268676618843e-06]
# ['nacional', 9.280537353237686e-06]
# ['meditatione', 4.640268676618843e-06]
# ['bnm', 4.640268676618843e-06]
# ['2652', 4.640268676618843e-06]
# ['centenario', 4.640268676618843e-06]
# ['actualmente', 4.640268676618843e-06]
# ['una', 9.280537353237686e-06]
# ['lburu', 4.640268676618843e-06]
# ['salamanca', 4.640268676618843e-06]
# ['1344', 4.640268676618843e-06]
# ['translations', 2.7841612059713052e-05]
# ['da', 1.3920806029856526e-05]
# ['1490', 4.640268676618843e-06]
# ['mention', 5.104295544280723e-05]
# ['cruz', 9.280537353237686e-06]
# ['1495', 4.640268676618843e-06]
# ['126', 9.280537353237686e-06]
# ['mu', 1.3920806029856526e-05]
# ['\\', -3.7704152778012527e-06]
# ['nez', 4.640268676618843e-06]
# ['nica', 9.280537353237686e-06]
# ['mb', 4.640268676618843e-06]
# ['cada', 4.640268676618843e-06]
# ['invencionario', 4.640268676618843e-06]
# ['humanist', 4.640268676618843e-06]
# ['admyte', 4.640268676618843e-06]
# ['contain', -3.7704152778012527e-06]
# ['gerson', 4.640268676618843e-06]
# ['biblioteca', 4.640268676618843e-06]
# ['works', -5.9371156913213466e-05]
# ['page', -7.370403524819412e-05]
# ['9219', 4.640268676618843e-06]
# ['11-109', 4.640268676618843e-06]
# ['folios', 4.640268676618843e-06]
# ['zaragoza', 9.280537353237686e-06]
# ['zaba', 4.640268676618843e-06]
# ['printout', -1.0997545581093729e-05]
# ['espan', 4.640268676618843e-06]
# ['bernardo', 9.280537353237686e-06]
# ['expresamente', 4.640268676618843e-06]
# ['0856', 4.640268676618843e-06]
# ['signatura', 4.640268676618843e-06]
# ['279', 4.640268676618843e-06]
# ['pablo', 1.3920806029856526e-05]
# ...
# ['v126n2630p14', 0.0]
# ['rewards', 0.0]
# ['obligation', 0.0]
# ['deregulation', 0.0]
# ['participating', 0.0]
# ['magazine', 0.0]
# ['telecommunications', 0.0]
# ['utility', 0.0]
# ['agreements', 0.0]
# ['federally', 0.0]
# ['1-800', 0.0]
# ['444-1050', 0.0]
# ['1997', 0.0]
# ['monopoly', 0.0]
# ['investors', 0.0]
# ['electric', 0.0]
# ['genuine', 0.0]
# ['consumers', 0.0]
# ['invest', 0.0]
# ['lifeline', 0.0]
# ['916-689', 0.0]
# ['offence', 0.0]
# ['021', 0.0]
# ['residing', 0.0]
# ['293', 0.0]
# ['leveraging', 0.0]
# ['convert', 0.0]
# ['780', 0.0]
# ['inexpensive', 0.0]
# ['76051', 0.0]
# ['2868', 0.0]
# ['grapevine', 0.0]
# ['nobrainer', 0.0]
# ['finances', 0.0]
# ['enable', 0.0]
# ['customer', 0.0]
# ['pull', 0.0]
# ['1511', 0.0]
# ['id', 0.0]
# ['4698', 0.0]
# ['peace', 0.0]
# ['cst', 0.0]
# ['mailer', 0.0]
# ['honestly', 0.0]
# ['duplicates', 0.0]
# ['gd', 0.0]
# ['causes', 0.0]
# ['tx', 0.0]
# ['undeliverables', 0.0]
# ['199', 0.0]
# ['cyber', 0.0]
# ['excess', 0.0]
# ['flamer', 0.0]
# ['buckley', 0.0]
# ['paste', 0.0]
# ['duplicate', 0.0]
# ['broke', 0.0]
# ['continual', 0.0]
# ['webmaster', 0.0]
# ['de-dupe', 0.0]
# ['clogs', 0.0]
# ['abuse', 0.0]
# ['updates', 0.0]
# ['houston', 0.0]
# ['cleanest', 0.0]
# ['highway', 0.0]
# ['toy', 0.0]
# ['released', 0.0]
# ['eliminated', 0.0]
# ['2693', 0.0]
# ['bulking', 0.0]
# ['cleaned', 0.0]
# ['mil', 0.0]
# ['storage', 0.0]
# ['postmaster', 0.0]
# ['cds', 0.0]
# ['keywords', 0.0]
# ['orleans', 0.0]
# ['colby', 0.0]
# ['995', 0.0]
# ['7-10', 0.0]
# ['amex', 0.0]
# ['profanity', 0.0]
# ['alot', 0.0]
# ['extracting', 0.0]
# ['tremendous', 0.0]
# ['production', 0.0]
# ['mci', 0.0]
# ['dave', 0.0]
# ['duping', 0.0]
# ['anon', 0.0]
# ['totally', 0.0]
# ['kid', 0.0]
# ['800-600', 0.0]
# ['adding', 0.0]
# ['1-212', 0.0]
# ['robbery', 0.0]
# ['reduced', 0.0]
# ['promos', 0.0]
# ['sex-related', 0.0]
# ['super', 0.0]
# ['vulgarity', 0.0]
# ['0343', 0.0]
# ['spam', 0.0]
# ['touted', 0.0]
# ['removes', 0.0]
# ['weekend', 0.0]
# ['504-8192', 0.0]
# ['solutions', 0.0]
# ['guides', 0.0]
# ['6-201', 0.0]
# ['consulting', 0.0]
# ['475', 0.0]
# ['worksheet', 0.0]
# ['bureaus', 0.0]
# ['pacificenter1', 0.0]
# ['ste', 0.0]
# ['brighten', 0.0]
# ['troubling', 0.0]
# ['92057', 0.0]
# ['enterprises', 0.0]
# ['creditors', 0.0]
# ['embarrased', 0.0]
# ['oceanside', 0.0]
# ['104', 0.0]
# ['unrealistic', 0.0]
# ['debts', 0.0]
# ['straightforward', 0.0]
# ['leases', 0.0]
# ['91607', 0.0]
# ['bills', 0.0]
# ['rents', 0.0]
# ['liens', 0.0]
# ['5318', 0.0]
# ['425-235', 0.0]
# ['2170', 0.0]
# ['bankruptcy', 0.0]
# ['disclose', 0.0]
# ['235-2206', 0.0]
# ['undersigned', 0.0]
# ['canyon', 0.0]
# ['7358', 0.0]
# ['818-769', 0.0]
# ['dmc', 0.0]
# ['2101', 0.0]
# ['2206', 0.0]
# ['driver', 0.0]
# ['818-763', 0.0]
# ['portion', 0.0]
# ['deposit', 0.0]
# ['us-ascii', 0.0]
# ['spidering', 0.0]
# ['crop', 0.0]
# ['click', 0.0]
# ['delimited', 0.0]
# ['win', 0.0]
# ['overnite', 0.0]
# ['yahoo', 0.0]
# ['praise', 0.0]
# ['charset', 0.0]
# ['keeps', 0.0]
# ['operations', 0.0]
# ['comma', 0.0]
# ['filters', 0.0]
# ['90036', 0.0]
# ['wilshire', 0.0]
# ['mime', 0.0]
# ['feed', 0.0]
# ['utilizes', 0.0]
# ['encoding', 0.0]
# ['7850', 0.0]
# ['doctors', 0.0]
# ['213-980', 0.0]
# ['imports', 0.0]
# ['built', 0.0]
# ['personalized', 0.0]
# ['surf', 0.0]
# ['5pm', 0.0]
# ['targeted', 0.0]
# ['cities', 0.0]
# ['5670', 0.0]
# ['urls', 0.0]
# ['259', 0.0]
# ['targeting', 0.0]
# ['engines', 0.0]
# ['collected', 0.0]
# ['website', 0.0]
# ['bull', 0.0]
# ['mouse', 0.0]
# ['authenticated', 0.0]
# ['7bit', 0.0]
# ['ads', 0.0]
# ['opp', 0.0]
# ['biz', 0.0]
# ['mumbo-jumbo', 0.0]
# ['export', 0.0]
# ['fedex', 0.0]
# ['florists', 0.0]
# ['imagination', 0.0]
# ['searches', 0.0]
# ['websites', 0.0]
# ['trials', 0.0]
# ['hey', 0.0]
# ['xxx', 0.0]
# ['aquariums', 0.0]
# ['hobbyist', 0.0]
# ['saltwater', 0.0]
# ['nationwide', 0.0]
# ['featuring', 0.0]
# ['captivesea', 0.0]
# ['aquarium', 0.0]
# ['manufacturer', 0.0]
# ['horizon', 0.0]
# ['cgi-win', 0.0]
# ['serving', 0.0]
# ['dicaprio', 0.0]
# ['porno', 0.0]
# ['brook', 0.0]
# ['whatsoever', 0.0]
# ['multi-part', 0.0]
# ['transfer-encoding', 0.0]
# ['leanardo', 0.0]
# ['password', 0.0]
# ['catches', 0.0]
# ['nude', 0.0]
# ['bunny', 0.0]
# ['celebs', 0.0]
# ['03', 0.0]
# ['shields', 0.0]
# ['disposition', 0.0]
# ['stockload', 0.0]
# ['pics', 0.0]
# ['brad', 0.0]
# ['901078729', 0.0]
# ['tons', 0.0]
# ['href', 0.0]
# ['strip', 0.0]
# ['legit', 0.0]
# ['teen', 0.0]
# ['amateur', 0.0]
# ['gay', 0.0]
# ['toon', 0.0]
# ['jul', 0.0]
# ['babs', 0.0]
# ['spammed', 0.0]
# ['hardcore', 0.0]
# ['teenhardcore', 0.0]
# ['clips', 0.0]
# ['loves', 0.0]
# ['showin', 0.0]
# ['hastle', 0.0]
# ['similiar', 0.0]
# ['hafta', 0.0]
# ['sdrack81', 0.0]
# ['rfc822', 0.0]
# ['rabit', 0.0]
# ['lesbian', 0.0]
# ['amateurporn', 0.0]
# ['part0', 0.0]
# ['inline', 0.0]
# ['chain', 0.0]
# ['brochure', 0.0]
# ['integrity', 0.0]
# ['dissatisfied', 0.0]
# ['187329', 0.0]
# ['sawmill', 0.0]
# ['choices', 0.0]
# ['coral', 0.0]
# ['printing', 0.0]
# ['revealing', 0.0]
# ['didn', 0.0]
# ['dumbest', 0.0]
# ['43235', 0.0]
# ['lottery', 0.0]
# ['proceed', 0.0]
# ['butler', 0.0]
# ['flat', 0.0]
# ['cheapest', 0.0]
# ['modified', 0.0]
# ['purchases', 0.0]
# ['sweetish', 0.0]
# ['multi-level', 0.0]
# ['fl', 0.0]
# ['2089', 0.0]
# ['1302', 0.0]
# ['deducted', 0.0]
# ['400', 0.0]
# ['outlined', 0.0]
# ['brody', 0.0]
# ['intrigued', 0.0]
# ['33077-0074', 0.0]
# ['advertisers', 0.0]
# ['cheat-proof', 0.0]
# ['deduct', 0.0]
# ['expecting', 0.0]
# ['458', 0.0]
# ['1342', 0.0]
# ['reaches', 0.0]
# ['wages', 0.0]
# ['participated', 0.0]
# ['770074', 0.0]
# ['kentwood', 0.0]
# ['consult', 0.0]
# ['stress-free', 0.0]
# ['beforehand', 0.0]
# ['rent', 0.0]
# ['wanting', 0.0]
# ['persistence', 0.0]
# ['altered', 0.0]
# ['dolbow', 0.0]
# ['newcomers', 0.0]
# ['cheat', 0.0]
# ['recipe', 0.0]
# ['chicken', 0.0]
# ['1301', 0.0]
# ['folded', 0.0]
# ['salespeople', 0.0]
# ['reveal', 0.0]
# ['honesty', 0.0]
# ['stamps', 0.0]
# ['hopefully', 0.0]
# ['7438', 0.0]
# ['avon', 0.0]
# ['brag', 0.0]
# ['resending', 0.0]
# ['laugh', 0.0]
# ['springs', 0.0]
# ['waterbury', 0.0]
# ['pierogies', 0.0]
# ['laser', 0.0]
# ['deductible', 0.0]
# ['sincere', 0.0]
# ['expenses', 0.0]
# ['tupperware', 0.0]
# ['ownership', 0.0]
# ['tune', 0.0]
# ['insure', 0.0]
# ['advertiser', 0.0]
# ['monitored', 0.0]
# ['equipment', 0.0]
# ['49508', 0.0]
# ['statistic', 0.0]
# ['classifieds', 0.0]
# ['mailers', 0.0]
# ['76', 0.0]
# ['throw', 0.0]
# ['culinary', 0.0]
# ['8000', 0.0]
# ['potato', 0.0]
# ['dramatically', 0.0]
# ['leveled', 0.0]
# ['specials', 0.0]
# ['299', 0.0]
# ['bonuses', 0.0]
# ['niche', 0.0]
# ['flames', 0.0]
# ['commonly', 0.0]
# ['697-0657', 0.0]
# ['interamp', 0.0]
# ['149', 0.0]
# ['anytime', 0.0]
# ['extractor', 0.0]
# ['emailer', 0.0]
# ['pegasus', 0.0]
# ['handy', 0.0]
# ['700', 0.0]
# ['frontier', 0.0]
# ['formula', 0.0]
# ['scary', 0.0]
# ['speeds', 0.0]
# ['de-compressing', 0.0]
# ['television', 0.0]
# ['shot', 0.0]
# ['autoresponders', 0.0]
# ['seperated', 0.0]
# ['insane', 0.0]
# ['delphi', 0.0]
# ['gentleman', 0.0]
# ['succeed', 0.0]
# ['1-561', 0.0]
# ['mega', 0.0]
# ['prodigy', 0.0]
# ['consuming', 0.0]
# ['bucks', 0.0]
# ['pad', 0.0]
# ['proirity', 0.0]
# ['genie', 0.0]
# ['modem', 0.0]
# ['amazed', 0.0]
# ['verion', 0.0]
# ['designers', 0.0]
# ['skeptical', 0.0]
# ['sends', 0.0]
# ['advertise', 0.0]
# ['remove-list', 0.0]
# ['pipeline', 0.0]
# ['wasting', 0.0]
# ['launching', 0.0]
# ['2500', 0.0]
# ['winzip', 0.0]
# ['fastfacts2', 0.0]
# ['dressings', 0.0]
# ['wound', 0.0]
# ['angelfire', 0.0]
# ['innovative', 0.0]
# ['internationally', 0.0]
# ['winning', 0.0]
# ['perth', 0.0]
# ['dressing', 0.0]
# ['continued', 0.0]
# ['6027', 0.0]
# ['elphick', 0.0]
# ['managing', 0.0]
# ['extensively', 0.0]
# ['trauma', 0.0]
# ['patient', 0.0]
# ['advantages', 0.0]
# ['manufacturing', 0.0]
# ['supplying', 0.0]
# ['dri', 0.0]
# ['innovations', 0.0]
# ['nursingone', 0.0]
# ['improvements', 0.0]
# ['protectors', 0.0]
# ['ca2', 0.0]
# ['hospital', 0.0]
# ['1807', 0.0]
# ['award', 0.0]
# ['618-9487', 0.0]
# ['nursing', 0.0]
# ['mullaloo', 0.0]
# ['hospitals', 0.0]
# ['kevin', 0.0]
# ['infection', 0.0]
# ['yulema', 0.0]
# ['exclusive', 0.0]
# ['760', 0.0]
# ['766', 0.0]
# ['765', 0.0]
# ['tours', 0.0]
# ['695', 0.0]
# ['699', 0.0]
# ['denver', 0.0]
# ['289', 0.0]
# ['819', 0.0]
# ['810', 0.0]
# ['fares', 0.0]
# ['935', 0.0]
# ['675', 0.0]
# ['715', 0.0]
# ['cincinati', 0.0]
# ['710', 0.0]
# ['269', 0.0]
# ['exclusives', 0.0]
# ['829', 0.0]
# ['360', 0.0]
# ['820', 0.0]
# ['frnkfrt', 0.0]
# ['zurich', 0.0]
# ['prague', 0.0]
# ['airfares', 0.0]
# ['milan', 0.0]
# ['670', 0.0]
# ['799', 0.0]
# ['520', 0.0]
# ['supplier', 0.0]
# ['7887', 0.0]
# ['losangeles', 0.0]
# ['newyork', 0.0]
# ['packages', 0.0]
# ['845', 0.0]
# ['840', 0.0]
# ['788', 0.0]
# ['789', 0.0]
# ['640', 0.0]
# ['510', 0.0]
# ['385', 0.0]
# ['5-bargain', 0.0]
# ['620', 0.0]
# ['65', 0.0]
# ['florence', 0.0]
# ['hotels', 0.0]
# ['budapest', 0.0]
# ['athens', 0.0]
# ['730', 0.0]
# ['735', 0.0]
# ['naples', 0.0]
# ['658', 0.0]
# ['vienna', 0.0]
# ['750', 0.0]
# ['705', 0.0]
# ['discounted', 0.0]
# ['202-898', 0.0]
# ['720', 0.0]
# ['725', 0.0]
# ['745', 0.0]
# ['lisbon', 0.0]
# ['warsaw', 0.0]
# ['749', 0.0]
# ['referrering', 0.0]
# ['770', 0.0]
# ['999', 0.0]
# ['778', 0.0]
# ['711', 0.0]
# ['79', 0.0]
# ['deluxe', 0.0]
# ['roundtrip', 0.0]
# ['800', 0.0]
# ['frankfurt', 0.0]
# ['bandwidth', 0.0]
# ['prepaid', 0.0]
# ['steal', 0.0]
# ['hosting', 0.0]
# ['unlock', 0.0]
# ['dial', 0.0]
# ['100k', 0.0]
# ['mate', 0.0]
# ['loose', 0.0]
# ['adressee', 0.0]
# ['advertsing', 0.0]
# ['3807', 0.0]
# ['298-7863', 0.0]
# ['om', 0.0]
# ['185', 0.0]
# ['relay', 0.0]
# ['98', 0.0]
# ['33611', 0.0]
# ['tampa', 0.0]
# ['caller', 0.0]
# ['398-9866', 0.0]
# ['mx', 0.0]
# ['demo', 0.0]
# ['888', 0.0]
# ['smtp', 0.0]
# ['excellant', 0.0]
# ['200k', 0.0]
# ['oak', 0.0]
# ['backbone', 0.0]
# ['bulkers', 0.0]
# ['dancers', 0.0]
# ['transmissions', 0.0]
# ['stopped', 0.0]
# ['conferencing', 0.0]
# ['301', 0.0]
# ['channels', 0.0]
# ['nuko64', 0.0]
# ['sexxxybodies', 0.0]
# ['oa', 0.0]
# ['1618', 0.0]
# ['gallery', 0.0]
# ['waterford', 0.0]
# ['net-tools', 0.0]
# ['534-7409', 0.0]
# ['reaching', 0.0]
# ['storefront', 0.0]
# ['complies', 0.0]
# ['entrepreneur', 0.0]
# ['loc', 0.0]
# ['ooo', 0.0]
# ['venture', 0.0]
# ['unwise', 0.0]
# ['dont', 0.0]
# ['bulk-friendly', 0.0]
# ['bypass', 0.0]
# ['3xd', 0.0]
# ['recipient', 0.0]
# ['discs', 0.0]
# ['camberley', 0.0]
# ['recieve', 0.0]
# ['unsolicited', 0.0]
# ['irritation', 0.0]
# ['imported', 0.0]
# ['puchased', 0.0]
# ['dispatched', 0.0]
# ['calcuated', 0.0]
# ['447', 0.0]
# ['packing', 0.0]
# ['travellers', 0.0]
# ['152', 0.0]
# ['1xt', 0.0]
# ['gu15', 0.0]
# ['163', 0.0]
# ['pound', 0.0]
# ['doman', 0.0]
# ['usefull', 0.0]
# ['prophoto', 0.0]
# ['1-10', 0.0]
# ['eligible', 0.0]
# ['void', 0.0]
# ['matched', 0.0]
# ['security', 0.0]
# ['291', 0.0]
# ['prohibited', 0.0]
# ['07031', 0.0]
# ['innaccuracy', 0.0]
# ['availible', 0.0]
# ['creditmatch', 0.0]
# ['ridge', 0.0]
# ['divorce', 0.0]
# ['convicted', 0.0]
# ['fraud', 0.0]
# ['denial', 0.0]
# ['sick', 0.0]
# ['unsecured', 0.0]
# ['creditor', 0.0]
# ['78', 0.0]
# ['falsification', 0.0]
# ['rejections', 0.0]
# ['520-615', 0.0]
# ['3253', 0.0]
# ['geocities', 0.0]
# ['pussyman', 0.0]
# ['mirror', 0.0]
# ['southbeach', 0.0]
# ['2325', 0.0]
# ['sexplosion', 0.0]
# ['thepussy', 0.0]
# ['dish', 0.0]
# ['hidden', 0.0]
# ['asians', 0.0]
# ['mouthful', 0.0]
# ['a001', 0.0]
# ['feeds', 0.0]
# ['teens', 0.0]
# ['orgies', 0.0]
# ['screen', 0.0]
# ['peep', 0.0]
# ['amateurs', 0.0]
# ['massage', 0.0]
# ['shoots', 0.0]
# ['cyberfolds', 0.0]
# ['rated', 0.0]
# ['signup', 0.0]
# ['cam', 0.0]
# ['mess', 0.0]
# ['dive', 0.0]
# ['skip', 0.0]
# ['buddy', 0.0]
# ['vietnamese', 0.0]
# ['stolen', 0.0]
# ['clients', 0.0]
# ['unlisted', 0.0]
# ['employees', 0.0]
# ['sleuth', 0.0]
# ['army', 0.0]
# ['desease', 0.0]
# ['tracing', 0.0]
# ['spy', 0.0]
# ['labor', 0.0]
# ['10pm', 0.0]
# ['ailment', 0.0]
# ['navy', 0.0]
# ['bargain', 0.0]
# ['marine', 0.0]
# ['flame', 0.0]
# ['malpractice', 0.0]
# ['poisons', 0.0]
# ['mia', 0.0]
# ['hazardous', 0.0]
# ['the-minute', 0.0]
# ['competitors', 0.0]
# ['renting', 0.0]
# ['publicity', 0.0]
# ['bureau', 0.0]
# ['hits', 0.0]
# ['phoning', 0.0]
# ['traded', 0.0]
# ['bernadette38', 0.0]
# ['annonymous', 0.0]
# ['sweetheart', 0.0]
# ['partner', 0.0]
# ['brides', 0.0]
# ['renters', 0.0]
# ['backround', 0.0]
# ['adoption', 0.0]
# ['phoebias', 0.0]
# ['enemies', 0.0]
# ['untraceable', 0.0]
# ['vendors', 0.0]
# ['grooms', 0.0]
# ['romantic', 0.0]
# ['cure', 0.0]
# ['fears', 0.0]
# ['spouse', 0.0]
# ['platter', 0.0]
# ['27804', 0.0]
# ['rocky', 0.0]
# ['hair', 0.0]
# ['toll', 0.0]
# ['600-0343', 0.0]
# ['assemble', 0.0]
# ['assemblers', 0.0]
# ['2425', 0.0]
# ['220', 0.0]
# ['270', 0.0]
# ['8950', 0.0]
# ['mount', 0.0]
# ['recording', 0.0]
# ['accessories', 0.0]
# ['crafts', 0.0]
# ['beaded', 0.0]
# ['04627caa', 0.0]
# ['350', 0.0]
# ['sleeves', 0.0]
# ['growth', 0.0]
# ['operation', 0.0]
# ['like-minded', 0.0]
# ['exotic', 0.0]
# ['one-time', 0.0]
# ['utilizing', 0.0]
# ['hands-on', 0.0]
# ['noveau', 0.0]
# ['turnkey', 0.0]
# ['scam', 0.0]
# ['roll', 0.0]
# ['junkemail', 0.0]
# ['thall14', 0.0]
# ['7-14', 0.0]
# ['wwweb', 0.0]
# ['ft', 0.0]
# ['moneyhelp', 0.0]
# ['sprynet', 0.0]
# ['ww', 0.0]
# ['optional', 0.0]
# ['commercialemail', 0.0]
# ['clicking', 0.0]
# ['796-6549', 0.0]
# ['41075', 0.0]
# ['debt-free', 0.0]
# ['murkowski', 0.0]
# ['emailamendtext', 0.0]
# ['208', 0.0]
# ['ky', 0.0]
# ['naughty', 0.0]
# ['freeweek', 0.0]
# ['discreetly', 0.0]
# ['compel', 0.0]
# ['walking', 0.0]
# ['billed', 0.0]
# ['swank', 0.0]
# ['unleashes', 0.0]
# ['dateline', 0.0]
# ['flirting', 0.0]
# ['1334', 0.0]
# ['pheromones', 0.0]
# ['androstenone', 0.0]
# ['vogue', 0.0]
# ['undetectable', 0.0]
# ['htm', 0.0]
# ['166', 0.0]
# ['vno', 0.0]
# ['passion', 0.0]
# ['bl', 0.0]
# ['inhaled', 0.0]
# ['concentrate', 0.0]
# ['wear', 0.0]
# ['invisible', 0.0]
# ['remainder', 0.0]
# ['85048', 0.0]
# ['penthouse', 0.0]
# ['packaging', 0.0]
# ['thera', 0.0]
# ['rejuvenate', 0.0]
# ['stimulation', 0.0]
# ['miraculously', 0.0]
# ['restraints', 0.0]
# ['chandler', 0.0]
# ['playboy', 0.0]
# ['unblocks', 0.0]
# ['5-a11', 0.0]
# ['impulse', 0.0]
# ['pheromone', 0.0]
# ['omni', 0.0]
# ['attractants', 0.0]
# ['chic', 0.0]
# ['bottles', 0.0]
# ['chemical', 0.0]
# ['irresistible', 0.0]
# ['arrouse', 0.0]
# ['30740', 0.0]
# ['attractiveness', 0.0]
# ['drastic', 0.0]
# ['unknowingly', 0.0]
# ['re-energize', 0.0]
# ['restores', 0.0]
# ['odorless', 0.0]
# ['thats', 0.0]
# ['84822', 0.0]
# ['retiring', 0.0]
# ['8511', 0.0]
# ['995-0796', 0.0]
# ['promotional', 0.0]
# ['freewebsites', 0.0]
# ['prosperous', 0.0]
# ['cearth', 0.0]
# ['seekers', 0.0]
# ['rating', 0.0]
# ['ga', 0.0]
# ['commissions', 0.0]
# ['breathing', 0.0]
# ['chainletter', 0.0]
# ['consolidation', 0.0]
# ['excited', 0.0]
# ['havens', 0.0]
# ['jamaica', 0.0]
# ['trails', 0.0]
# ['obsolete', 0.0]
# ['ruthless', 0.0]
# ['harassing', 0.0]
# ['mad', 0.0]
# ['protection', 0.0]
# ['priceless', 0.0]
# ['fortune', 0.0]
# ['bundles', 0.0]
# ['asset', 0.0]
# ['survive', 0.0]
# ['ibc', 0.0]
# ['atm', 0.0]
# ['heartless', 0.0]
# ['inheritance', 0.0]
# ['technicians', 0.0]
# ['offshore', 0.0]
# ['stock', 0.0]
# ['rude', 0.0]
# ['filthy', 0.0]
# ['baggage', 0.0]
# ['cloaking', 0.0]
# ['devote', 0.0]
# ['brainer', 0.0]
# ['sucking', 0.0]
# ['stinking', 0.0]
# ['yeah', 0.0]
# ['tenth', 0.0]
# ['trusts', 0.0]
# ['americans', 0.0]
# ['viable', 0.0]
# ['greedy', 0.0]
# ['duplicatable', 0.0]
# ['brakets', 0.0]
# ['privacy', 0.0]
# ['rubbing', 0.0]
# ['postcards', 0.0]
# ['mercy', 0.0]
# ['financing', 0.0]
# ['self-employed', 0.0]
# ['richer', 0.0]
# ['limiting', 0.0]
# ['risks', 0.0]
# ['borrowing', 0.0]
# ['partnership', 0.0]
# ['co-op', 0.0]
# ['sells', 0.0]
# ['forced', 0.0]
# ['answering', 0.0]
# ['purchasing', 0.0]
# ['brace', 0.0]
# ['unparalleled', 0.0]
# ['accountants', 0.0]
# ['234-4241', 0.0]
# ['hungry', 0.0]
# ['incorporate', 0.0]
# ['pennies', 0.0]
# ['hrs', 0.0]
# ['stabbing', 0.0]
# ['initally', 0.0]
# ['spun', 0.0]
# ['aaa', 0.0]
# ['reprint', 0.0]
# ['5599', 0.0]
# ['officially', 0.0]
# ['medicines', 0.0]
# ['borrow', 0.0]
# ['yield', 0.0]
# ['reprints', 0.0]
# ['cringe', 0.0]
# ['audited', 0.0]
# ['24hrs', 0.0]
# ['decatur', 0.0]
# ['bulk-email', 0.0]
# ['restricting', 0.0]
# ['parent', 0.0]
# ['kitchen', 0.0]
# ['millionaire', 0.0]
# ['liquidating', 0.0]
# ['receives', 0.0]
# ['wheels', 0.0]
# ['50-50', 0.0]
# ['anyplace', 0.0]
# ['aback', 0.0]
# ['decent', 0.0]
# ['digits', 0.0]
# ['innocent', 0.0]
# ['274-8669', 0.0]
# ['dialing', 0.0]
# ['373-356', 0.0]
# ['engineers', 0.0]
# ['provocative', 0.0]
# ['blackballed', 0.0]
# ['frivolous', 0.0]
# ['audit', 0.0]
# ['presses', 0.0]
# ['ofs', 0.0]
# ['residuals', 0.0]
# ['settlements', 0.0]
# ['unfair', 0.0]
# ['bankcards', 0.0]
# ['self-liquidating', 0.0]
# ['retired', 0.0]
# ['hardworking', 0.0]
# ['discriminatory', 0.0]
# ['secrecy', 0.0]
# ['measly', 0.0]
# ['imposed', 0.0]
# ['patience', 0.0]
# ['postcard', 0.0]
# ['burdens', 0.0]
# ['30037-3356', 0.0]
# ['trust', 0.0]
# ['cassette', 0.0]
# ['flyers', 0.0]
# ['broker', 0.0]
# ['floppy', 0.0]
# ['architects', 0.0]
# ['infomercials', 0.0]
# ['banker', 0.0]
# ['persuaded', 0.0]
# ['billions', 0.0]
# ['airlines', 0.0]
# ['responds', 0.0]
# ['sneaky', 0.0]
# ['removing', 0.0]
# ['dynamite', 0.0]
# ['strict', 0.0]
# ['fda', 0.0]
# ['stealing', 0.0]
# ['chat', 0.0]
# ['bragging', 0.0]
# ['junk', 0.0]
# ['energetic', 0.0]
# ['regulations', 0.0]
# ['over-rides', 0.0]
# ['extras', 0.0]
# ['merchant', 0.0]
# ['aforementioned', 0.0]
# ['honored', 0.0]
# ['accounts', 0.0]
# ['cancel', 0.0]
# ['creditime', 0.0]
# ['haveing', 0.0]
# ['inability', 0.0]
